# %% [markdown]
# # Python
# ## Task 1
# ### A. Python is an indent based programming language
# The following program throws an indentation error. Correct it and make sure it prints properly.
#
# teams = ['Data', 'AI', 'DevOps']
# for t in teams:
# print('Hello', t, 'Team from Inceptez Technologies')
#   print('Keep Learning and Exploring!')

# %%
teams = ['Data', 'AI', 'DevOps']
for t in teams:
    print('Hello', t, 'Team from Inceptez Technologies')
    print('Keep Learning and Exploring!')

# %% [markdown]
# ### B. Commented line in Python
# Use Case 1:
# Add single-line and multi-line comments to describe what the below code does for Inceptez Technologies’ training tracker.
#
# students = 100
# trainers = 2
# total = students + trainers
# print(total)

# %%
''''calculate total number of people in the training program'''
students = 100
trainers = 2
#calculation
total = students + trainers
print('total number of students:', students)
print('total number of trainers:', trainers)
print('total number of people:', total)

# %% [markdown]
# Use Case 2:
# Convert the below block into a “dead code” using comments, then re-activate it later to print
#
# print("Welcome to Inceptez Python Learning")

# %%
# print("Welcome to Inceptez Python Learning")

# %% [markdown]
# ### C. Playing with Quotes
# Use Case 1:
# Create three string variables that correctly store and print:
#
# This is Inceptez's "Python" class for Data Engineers & AI Engineers
# → Use single, double, and triple quotes appropriately.

# %%
one = 'This is Inceptez\'s "Python" class for Data Engineers & AI Engineers'
two = "This is Inceptez's \"Python\" class for Data Engineers & AI Engineers"
three = """This is Inceptez's "Python" class for Data Engineers & AI Engineers"""

print(one, two, three, sep='\n')

# %% [markdown]
# Use Case 2:
# Write a multiline string using triple quotes that prints:
#
# Welcome to Inceptez Technologies!
# Python Training: Basics
# Enjoy your learning journey.

# %%
print ("""Welcome to Inceptez Technologies!
Python Training: Basics
Enjoy your learning journey.""")

# %% [markdown]
# ### D. Let's learn all about VARIABLES
# Use Case 1:
# Declare variables to store the following details:
# - Student Name
# - Course Name (e.g., “Python")
# - Training Institute Name (ABC tech)
#
# Then print a formatted message:
#
# Name: Apple is learning the course Python Fundamentals at the institute ABC Technologies

# %%
studentName = 'Apple'
courseName = 'Python'
trainingInstitute = 'ABC Tech'
print(studentName, 'is learning the course', courseName, 'at the', trainingInstitute)

# %% [markdown]
# Use Case 2:
# Demonstrate dynamic inference, dynamic typing using with fee by applying .18 gst  and prove strongly typing character also by operating it with Eighteen percent gst
#
# fee = 45000

# %%
# Demonstrate dynamic inference, dynamic typing using with fee by applying .18 gst  and prove strongly typing character also by operating it with Eighteen percent gst
fee =45000
gst = 0.18
total_fee = fee + (fee * gst)

print(f"The total fee {fee} + including GST {gst} is {total_fee}")

# %% [markdown]
# ### E. Variables Naming Conventions
# Use Case 1:
# Identify which variable names below are invalid for abc student database:
#
# 1) 2student = 'Ravi'
# 2) _student_id = 1001
# 3) studentName = 'Priya'
# 4) class name = 'Python'
# 5) inceptez_batch = 'Morning'

# %%
_student_id = 1001
print(_student_id)

inceptez_batch = 'Morning'
print(inceptez_batch)

studentName = 'Priya'
print(studentName)

#invalid variable names below two
2student = 'Ravi'
print(2student)

class name = 'Python'
print(class name)

# %% [markdown]
# Use Case 2:
# Declare 3 variables following naming styles for abc projects:
#
# PascalCase: DataEngineeringBatch
# camelCase: dataEngineeringBatch
# snake_case: data_engineering_batch

# %%
DataEngineeringBatch = 'PascalCase'
dataEngineeringBatch = 'camelCase'
data_engineering_batch = 'snake_case'
print(DataEngineeringBatch, dataEngineeringBatch, data_engineering_batch, sep='\n')

# %% [markdown]
# ### F. Type identification & Casting
# Use Case 1:
# Sample code: As we didn’t covered this function input() yet in our session, I am giving the below sample code for your reference.
# Write a program that asks for an employee’s age.
#
# 1. Checks its type is of string
# print(type(age))
# 2. Converts it to int (continue writing your program from here..)
# 3. Prints the years pending for retirement, for eg. 60 is the retirement age.

# %%
age = input("Enter your age: ")
print("type of variable age is:", type(age))
age = int(age)
print("type of variable age is converted to :", type(age))

retirement_age = 60
age_left_for_retirement = (retirement_age - age)

if age_left_for_retirement > 0:
    print(f"Your age is: {age} and you have {age_left_for_retirement} years left for your retirement ")
else:
    print(f"Your age is: {age} and you have already retired age")

# %% [markdown]
# Use Case 2 (Debug):
# Fix the type error in the following code for salary calculation:
#
# salary = '50000'
# bonus = 10000
# print('Total Salary in abc:', salary + bonus)

# %%
salary = '50000'
bonus = 10000
salary = int(salary)
bonus = int(bonus)
print('Total Salary in abc:', salary + bonus)

# %% [markdown]
# ### G. Data types and casting
# Use Case 1 — Employee Salary Breakdown Using Numeric & String Types
# Employee Salary Breakdown
#
# a. Write a program that asks the user for: employee_name (string).
# base_salary (float).
# hra_percent (integer).
# bonus_amount (float).
#
# B. Convert inputs to the correct datatype if required.
# Calculate:
#  HRA = base_salary * (hra_percent / 100)
#  Total Salary = base_salary + HRA + bonus_amount
#
# C. Print the output

# %%
#a
employee_name = input("Enter employee name: ")
base_salary = float(input("Enter base salary: "))
hra_percent = int(input("Enter HRA percentage: "))
bonus_amount = float(input("Enter bonus amount: "))

#b
hra_amount = (base_salary * hra_percent) / 100
total_salary = base_salary + hra_amount + bonus_amount

#c
print(f"Employee Name: {employee_name}")
print(f"Base Salary: {base_salary}")
print(f"HRA Percentage: {hra_percent}")
print(f"Bonus Amount: {bonus_amount}")
print(f"HRA Amount: {hra_amount}") 
print(f"Total Salary: {total_salary}")

# %% [markdown]
# Use Case 2:
# Student Result Classification<br>
# a. Write a program that takes marks as input (initially as a string). <br>
# B. Check if the value can be converted to float.<br>
# C. Then classify (try using if condition with the help of AI, however we will learn about if condition soon):
# Marks >= 90 --> Outstanding
#  Marks >= 75 --> Excellent
#  Marks >= 50 --> Pass
#  Marks < 50 --> Fail<br>
# D. If the input is not numeric, print:
#  Invalid marks entered — Please provide numeric input.

# %%
#Student Result Classification
#Write a program that takes marks as input (initially as a string). 
marks = input("Enter marks: ")

#Check if the value can be converted to float.
try:
    marks = float(marks)
#Then classify (try using if condition with the help of AI, however we will learn about if condition soon):
    if marks < 0 or marks > 100:
        print("Invalid marks entered. Please enter a value between 0 and 100.")
    elif marks >= 90:
        print("Outstanding")
    elif marks >= 75:
        print("Excellent")
    elif marks >= 50:
        print("Pass")
    else:
        print("Fail")
#If the input is not numeric, print:
except ValueError:
    print("Invalid marks entered — Please provide numeric input.")

# %% [markdown]
# Use Case 3: Bug Fixing — Datatype Mismatch
#
# The below code is intended to calculate total price, but it has datatype errors. Fix it.
# Incorrect code:
# item_name = input("Enter product name: ")
#  price = input("Enter price per item: ")
#  quantity = input("Enter quantity: ")
# total_cost = price * quantity
# print("You purchased " + quantity + " units of " + item_name)
#  print("Total payable: " + total_cost)
# Expected output after fixing:
# Enter product name: Notepad
#  Enter price per item: 35.50
#  Enter quantity: 3
# You purchased 3 units of Notepad
#  Total payable: 106.5 INR

# %%
item_name = input("Enter product name: ")
price = float(input("Enter price per item: "))
quantity = int(input("Enter quantity: "))
total_cost = price * quantity
print("You purchased " + str(quantity) + " units of " + item_name)
print("Total payable: " + str(total_cost) + " INR")

# %% [markdown]
# ### H. Python Operators Usecases
#
# Use Case 1: Internet Data Usage Calculator
# Write a program that asks the user for:
# Total monthly data limit (in GB)
# Data used so far (in GB)
#
#
# Calculate using arithmetic operators:
#  Remaining data = limit - used
#  Usage percentage = (used / limit) * 100
# Print:
# Remaining data
# Usage percentage rounded to 2 decimals
#
#
# If usage percentage is greater than or equal to 80, print:
#  "Warning: High usage, consider upgrading your plan."

# %%
#Calculate using arithmetic operators:
monthly_data_limit = int(input("Enter data limit in GB: "))
data_used = int(input("Enter data used in GB: "))
remaining_data = monthly_data_limit - data_used
usage_percentage = (data_used / monthly_data_limit) * 100
print(f"Remaining data: {remaining_data} GB")       
print(f"Data usage percentage: {usage_percentage:.2f}%")
if usage_percentage > 80:
    print(f"Warning: You have used more than {usage_percentage:.2f}% of your data limit.")
else:
    print(f"You have used {usage_percentage:.2f}% of your data limit. You are within the safe usage range.")
# Out:
# Remaining data: 72 GB
# Data usage percentage: 8.861%
# You have used 8.86% of your data limit. You are within the safe usage range.

# %% [markdown]
# Use Case 2: Shopping Discount Calculation
# Write a program that takes:
# Original price (float)
# Discount percent (int)
#
#
# Using assignment and arithmetic operators, calculate:
#  Discount amount = (price * discount_percent) / 100
#  Final price = price - discount_amount
# Print:
#  Original price, discount applied, and final payable amount.

# %%
original_price = float(input("Enter original price: "))
discount_percentage = float(input("Enter discount percentage: "))
discount_amount = (original_price * discount_percentage) / 100
final_price = original_price - discount_amount
print(f"Original Price: {original_price}")
print(f"Discount Percentage: {discount_percentage}%")
print(f"Discount Amount: {discount_amount}")
print(f"Final Price after discount: {final_price}")
# Out:
# Original Price: 1000.0
# Discount Percentage: 10.0%
# Discount Amount: 100.0
# Final Price after discount: 900.0

# %% [markdown]
# Use Case 3 (Bug Fixing): Logical and Comparison Operator Errors
# The following code should determine voting eligibility, but it contains operator mistakes. Fix it.
# Incorrect code:
# age = input("Enter age: ")
#  citizen = input("Are you an Indian citizen? (yes/no)")
# if age > "18" and citizen = "yes":
#  print("Eligible to vote")
#  else:
#  print("Not eligible")
# Expected behavior:
# Convert age to integer before comparison.
#
#
# Only print "Eligible to vote" if age is 18 or above AND citizen input is "yes" (case-insensitive).

# %%
age = int(input("Enter age: "))
citizen = input("Are you an Indian citizen? (yes/no)")
if age > 18 and citizen in( "yes", "Yes"):
   print("Eligible to vote")
else:
    if age <= 18:
        print("Not eligible: Age must be greater than 18.")
    elif citizen.lower() != "yes":
        print("Not eligible: Must be an Indian citizen.")
    print("Not eligible")
# Out:
# Not eligible: Must be an Indian citizen.
# Not eligible
